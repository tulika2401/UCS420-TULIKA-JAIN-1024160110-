# %%
roll_no = input("Enter your roll number: ")
digits = [int(digit) for digit in roll_no] 
L = [digit * 10 for digit in digits]

# %%
print("The list of digits multiplied by 10 is:", L)
# Out:
# The list of digits multiplied by 10 is: [10, 0, 20, 40, 10, 60, 0, 10, 10, 0]

# %%
L.append(50)

# %%
L.append(50)

print("After append:", L)
# Out:
# After append: [10, 0, 20, 40, 10, 60, 0, 10, 10, 0, 50, 50]

# %%
L.insert(2, 70)

print("After insert:", L)
# Out:
# After insert: [10, 0, 70, 20, 40, 10, 60, 0, 10, 10, 0, 50, 50]

# %%
L.remove(50)

print("After remove:", L)
# Out:
# After remove: [10, 0, 70, 20, 40, 10, 60, 0, 10, 10, 0, 50]

# %%
removed = L.pop()

print("Removed element:", removed)
print("After pop:", L)
# Out:
# Removed element: 50
# After pop: [10, 0, 70, 20, 40, 10, 60, 0, 10, 10, 0]

# %%
L.sort()

print("Ascending order:", L)
# Out:
# Ascending order: [0, 0, 0, 10, 10, 10, 10, 20, 40, 60, 70]

# %%
L.sort(reverse=True)

print("Descending order:", L)
# Out:
# Descending order: [70, 60, 40, 20, 10, 10, 10, 10, 0, 0, 0]

# %%
print("First three elements:", L[:3])
print("Last three elements:", L[-3:])
# Out:
# First three elements: [70, 60, 40]
# Last three elements: [0, 0, 0]

# %%
average = sum(L) / len(L)

greater = [x for x in L if x > average]

print("Average:", average)
print("Elements greater than average:", greater)
# Out:
# Average: 20.90909090909091
# Elements greater than average: [70, 60, 40]

# %%
scores = tuple(L[:8])

print("Scores:", scores)
# Out:
# Scores: (70, 60, 40, 20, 10, 10, 10, 10)

# %%
highest_score=max(scores)
highest_index = scores.index(highest_score)
print("Highest score:", highest_score)  
print("Index of highest score:", highest_index)
# Out:
# Highest score: 70
# Index of highest score: 0

# %%
lowest = min(scores)
lowest_count = scores.count(lowest)

print("Lowest score:", lowest)
print("Number of times lowest appears:", lowest_count)
# Out:
# Lowest score: 10
# Number of times lowest appears: 4

# %%
reversed_scores = list(reversed(scores))

print("Reversed tuple as list:", reversed_scores)
# Out:
# Reversed tuple as list: [10, 10, 10, 10, 20, 40, 60, 70]

# %%
score = int(input("Enter a score: "))

if score in scores:
    print("First occurrence index:", scores.index(score))
else:
    print("Score is not present in the tuple.")
# Out:
# Score is not present in the tuple.

# %%
scores[0] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_635/1957282536.py in <cell line: 0>()
# ----> 1 scores[0] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %%
try:
    scores[0] = 100
except TypeError as e:
    print("Error:", e)
    print("Tuple cannot be modified because it is immutable.")
# Out:
# Error: 'tuple' object does not support item assignment
# Tuple cannot be modified because it is immutable.

# %%
first_score, second_score, *remaining_scores = scores

print("First score:", first_score)
print("Second score:", second_score)
print("Remaining scores:", remaining_scores)
# Out:
# First score: 70
# Second score: 60
# Remaining scores: [40, 20, 10, 10, 10, 10]

# %%
import random

roll_no = int(input("Enter your roll number: "))

random.seed(roll_no)

# %%
numbers = [random.randint(100, 900) for _ in range(100)]

print(numbers)
# Out:
# [427, 351, 712, 374, 856, 431, 801, 756, 552, 717, 298, 580, 214, 319, 439, 882, 776, 357, 779, 732, 296, 131, 879, 815, 228, 522, 636, 740, 388, 342, 502, 496, 581, 797, 754, 265, 804, 369, 441, 858, 417, 562, 505, 518, 493, 241, 308, 702, 114, 275, 443, 814, 279, 304, 807, 233, 449, 281, 567, 571, 157, 820, 149, 725, 189, 845, 264, 779, 103, 623, 361, 101, 154, 272, 308, 575, 280, 744, 385, 611, 289, 782, 624, 472, 634, 130, 273, 452, 442, 234, 871, 203, 613, 738, 563, 819, 618, 627, 821, 269]

# %%
odd_numbers = [x for x in numbers if x % 2 != 0]

print("Odd numbers:", odd_numbers)
print("Count of odd numbers:", len(odd_numbers))
# Out:
# Odd numbers: [427, 351, 431, 801, 717, 319, 439, 357, 779, 131, 879, 815, 581, 797, 265, 369, 441, 417, 505, 493, 241, 275, 443, 279, 807, 233, 449, 281, 567, 571, 157, 149, 725, 189, 845, 779, 103, 623, 361, 101, 575, 385, 611, 289, 273, 871, 203, 613, 563, 819, 627, 821, 269]
# Count of odd numbers: 53

# %%
even_numbers = [x for x in numbers if x % 2 == 0]

print("Even numbers:", even_numbers)
print("Count of even numbers:", len(even_numbers))
# Out:
# Even numbers: [712, 374, 856, 756, 552, 298, 580, 214, 882, 776, 732, 296, 228, 522, 636, 740, 388, 342, 502, 496, 754, 804, 858, 562, 518, 308, 702, 114, 814, 304, 820, 264, 154, 272, 308, 280, 744, 782, 624, 472, 634, 130, 452, 442, 234, 738, 618]
# Count of even numbers: 47

# %%
def is_prime(n):
    if n < 2:
        return False

    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False

    return True

# %%
prime_numbers = [x for x in numbers if is_prime(x)]

print("Prime numbers:", prime_numbers)
print("Count of prime numbers:", len(prime_numbers))
# Out:
# Prime numbers: [431, 439, 131, 797, 241, 443, 233, 449, 281, 571, 157, 149, 103, 101, 613, 563, 821, 269]
# Count of prime numbers: 18

# %%
frequency = {}

for x in numbers:
    frequency[x] = frequency.get(x, 0) + 1

print(frequency)
# Out:
# {427: 1, 351: 1, 712: 1, 374: 1, 856: 1, 431: 1, 801: 1, 756: 1, 552: 1, 717: 1, 298: 1, 580: 1, 214: 1, 319: 1, 439: 1, 882: 1, 776: 1, 357: 1, 779: 2, 732: 1, 296: 1, 131: 1, 879: 1, 815: 1, 228: 1, 522: 1, 636: 1, 740: 1, 388: 1, 342: 1, 502: 1, 496: 1, 581: 1, 797: 1, 754: 1, 265: 1, 804: 1, 369: 1, 441: 1, 858: 1, 417: 1, 562: 1, 505: 1, 518: 1, 493: 1, 241: 1, 308: 2, 702: 1, 114: 1, 275: 1, 443: 1, 814: 1, 279: 1, 304: 1, 807: 1, 233: 1, 449: 1, 281: 1, 567: 1, 571: 1, 157: 1, 820: 1, 149: 1, 725: 1, 189: 1, 845: 1, 264: 1, 103: 1, 623: 1, 361: 1, 101: 1, 154: 1, 272: 1, 575: 1, 280: 1, 744: 1, 385: 1, 611: 1, 289: 1, 782: 1, 624: 1, 472: 1, 634: 1, 130: 1, 273: 1, 452: 1, 442: 1, 234: 1, 871: 1, 203: 1, 613: 1, 738: 1, 563: 1, 819: 1, 618: 1, 627: 1, 821: 1, 269: 1}

# %%
most_frequent = max(frequency, key=frequency.get)

print("Most frequent number:", most_frequent)
print("Number of times it occurs:", frequency[most_frequent])
# Out:
# Most frequent number: 779
# Number of times it occurs: 2

# %%
roll_no = input("Enter your roll number: ")

digits = [int(digit) for digit in roll_no]

print("Digits:", digits)
# Out:
# Digits: [1, 0, 2, 4, 1, 6, 0, 1, 1, 0]

# %%
A = {digit * 7 for digit in digits}
B = {digit * 9 for digit in digits}

print("Set A:", A)
print("Set B:", B)
# Out:
# Set A: {0, 7, 42, 14, 28}
# Set B: {0, 36, 9, 18, 54}

# %%
union = A.union(B)

print("Union:", union)
# Out:
# Union: {0, 36, 7, 9, 42, 14, 18, 54, 28}

# %%
intersection = A.intersection(B)

print("Intersection:", intersection)
# Out:
# Intersection: {0}

# %%
A_minus_B = A.difference(B)

print("A - B:", A_minus_B)
# Out:
# A - B: {42, 28, 14, 7}

# %%
B_minus_A = B.difference(A)

print("B - A:", B_minus_A)
# Out:
# B - A: {9, 18, 36, 54}

# %%
symmetric_difference = A.symmetric_difference(B)

print("Symmetric Difference:", symmetric_difference)
# Out:
# Symmetric Difference: {7, 9, 14, 18, 28, 36, 42, 54}

# %%
print("Is A a subset of B?", A.issubset(B))
# Out:
# Is A a subset of B? False

# %%
print("Is B a superset of A?", B.issuperset(A))
# Out:
# Is B a superset of A? False

# %%
X = int(input("Enter a value X: "))

A.discard(X)

print("Set A after discard:", A)
# Out:
# Set A after discard: {0, 7, 42, 14, 28}

# %%
my_dict = {
    "name": "Tulika Jain",
    "roll_no": "1024160110",
    "branch": "CSE",
    "age": 20,
    "city": "Jaipur"
}

print(my_dict)
# Out:
# {'name': 'Tulika Jain', 'roll_no': '1024160110', 'branch': 'CSE', 'age': 20, 'city': 'Jaipur'}

# %%
my_dict["location"] = my_dict.pop("city")

print(my_dict)
# Out:
# {'name': 'Tulika Jain', 'roll_no': '1024160110', 'branch': 'CSE', 'age': 20, 'location': 'Jaipur'}

# %%
my_dict["cgpa"] = 8.23

print(my_dict)
# Out:
# {'name': 'Tulika Jain', 'roll_no': '1024160110', 'branch': 'CSE', 'age': 20, 'location': 'Jaipur', 'cgpa': 8.23}

# %%
my_dict["age"] = my_dict["age"] + 1

print(my_dict)
# Out:
# {'name': 'Tulika Jain', 'roll_no': '1024160110', 'branch': 'CSE', 'age': 21, 'location': 'Jaipur', 'cgpa': 8.23}

# %%
dict_pop = my_dict.copy()

removed_value = dict_pop.pop("branch")

print("Dictionary:", dict_pop)
print("Removed value:", removed_value)
# Out:
# Dictionary: {'name': 'Tulika Jain', 'roll_no': '1024160110', 'age': 21, 'location': 'Jaipur', 'cgpa': 8.23}
# Removed value: CSE

# %%
dict_del = my_dict.copy()

del dict_del["branch"]

print("Dictionary:", dict_del)
# Out:
# Dictionary: {'name': 'Tulika Jain', 'roll_no': '1024160110', 'age': 21, 'location': 'Jaipur', 'cgpa': 8.23}

# %%
for key, value in my_dict.items():
    print(key, "→", value)
# Out:
# name → Tulika Jain
# roll_no → 1024160110
# branch → CSE
# age → 21
# location → Jaipur
# cgpa → 8.23

# %%
if "email" in my_dict:
    print("Email:", my_dict["email"])
else:
    print("Email does not exist in the dictionary.")
# Out:
# Email does not exist in the dictionary.

# %%
friend_dict = {
    "name": "geet rawal",
    "roll_no": "1024160012",
    "branch": "CSE",
    "age": 20,
    "city": "ludhiana"
}

print(friend_dict)
# Out:
# {'name': 'geet rawal', 'roll_no': '1024160012', 'branch': 'CSE', 'age': 20, 'city': 'ludhiana'}

# %%
merged_dict = {**my_dict, **friend_dict}

print("Merged dictionary:", merged_dict)
# Out:
# Merged dictionary: {'name': 'geet rawal', 'roll_no': '1024160012', 'branch': 'CSE', 'age': 20, 'location': 'Jaipur', 'cgpa': 8.23, 'city': 'ludhiana'}

# %%
string_values = {
    key: value
    for key, value in my_dict.items()
    if isinstance(value, str)
}

print("String values:", string_values)
# Out:
# String values: {'name': 'Tulika Jain', 'roll_no': '1024160110', 'branch': 'CSE', 'location': 'Jaipur'}
