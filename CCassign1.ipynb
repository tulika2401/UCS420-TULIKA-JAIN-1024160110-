# %%
print("Tulika Jain")
print("Tulika Jain")
print("Tulika Jain")
# Out:
# Tulika Jain
# Tulika Jain
# Tulika Jain

# %%
num1 = 10
num2 = 20
num3 = 30

sum = num1 + num2 + num3

print("Sum =", sum)
# Out:
# Sum = 60

# %%
a = "Thapar"
b = "University"
c="Patiala"
c = a + b + c		# Concatinate two strings
print (a, " + ", b, " + ", c, " --> ", c)
# Out:
# Thapar  +  University  +  ThaparUniversityPatiala  -->  ThaparUniversityPatiala

# %%
print("Table of 7")
for i in range(1, 11):
    print("7 x", i, "=", 7 * i)

print()

print("Table of 9")
for i in range(1, 11):
    print("9 x", i, "=", 9 * i)
# Out:
# Table of 7
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70
#
# Table of 9
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81
# 9 x 10 = 90

# %%
n = int(input("Enter a number: "))

print("Table of", n)

for i in range(1, 11):
    print(n, "x", i, "=", n * i)
# Out:
# Table of 7
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70

# %%
n = int(input("Enter a number: "))

sum = 0

for i in range(1, n + 1):
    sum = sum + i

print("Sum of numbers from 1 to", n, "is", sum)
# Out:
# Sum of numbers from 1 to 9 is 45

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
num3 = int(input("Enter third number: "))

maximum = max(num1, num2, num3)

print("The maximum number is:", maximum)
# Out:
# The maximum number is: 8

# %%
n = int(input("Enter a number: "))

sum = 0

for i in range(1, n + 1):
    if i % 7 == 0 and i % 9 == 0:
        sum = sum + i

print("Sum of numbers divisible by 7 and 9 is:", sum)
# Out:
# Sum of numbers divisible by 7 and 9 is: 0

# %%
n = int(input("Enter a number: "))

sum = 0

for i in range(2, n + 1):
    prime = True

    for j in range(2, i):
        if i % j == 0:
            prime = False
            break

    if prime:
        sum = sum + i

print("Sum of all prime numbers from 1 to", n, "is", sum)
# Out:
# Sum of all prime numbers from 1 to 8 is 17

# %%
def add_odd(n):
    sum = 0
    for i in range(1, n + 1):
        if i % 2 != 0:
            sum = sum + i
    return sum

n = int(input("Enter a number: "))

result = add_odd(n)

print("Sum of all odd numbers from 1 to", n, "is", result)
# Out:
# Sum of all odd numbers from 1 to 8 is 16

# %%
def add_prime(n):
    sum = 0

    for i in range(2, n + 1):
        prime = True

        for j in range(2, i):
            if i % j == 0:
                prime = False
                break

        if prime:
            sum = sum + i

    return sum

n = int(input("Enter a number: "))

result = add_prime(n)

print("Sum of all prime numbers from 1 to", n, "is", result)
# Out:
# Sum of all prime numbers from 1 to 9 is 17
